# %%
import pandas as pd

x1 = []
x2 = []
x3 = []
x4 = []
x5 = []

with open("E:\data_banknote_authentication.txt") as file:
    for line in file:
        line = line.split("\n")[0]
        list = line.split(",") 
        x1.append(list[0])
        x2.append(list[1])
        x3.append(list[2])
        x4.append(list[3])
        x5.append(list[4])

table = pd.DataFrame({})
for i in range(len(x1)):
    table[i+1] = [x1[i], x2[i], x3[i], x4[i], x5[i]]
table.index = ["x1", "x2", "x3", "x4", "x5"]
table.head()
# Out:
#         1        2        3        4        5        6        7         8     \
# x1    3.6216   4.5459    3.866   3.4566  0.32924   4.3684   3.5912    2.0922
# x2    8.6661   8.1674  -2.6383   9.5228  -4.4552   9.6718   3.0129     -6.81
# x3   -2.8073  -2.4586   1.9242  -4.0112   4.5718  -3.9606  0.72888    8.4636
# x4  -0.44699  -1.4621  0.10645  -3.5944  -0.9888  -3.1625  0.56421  -0.60216
# x5         0        0        0        0        0        0        0         0
#
#         9         10    ...      1363     1364      1365      1366      1367  \
# x1    3.2032    1.5356  ...   -2.1668  -1.1667   -2.8391   -4.5046     -2.41
# x2    5.7588    9.1772  ...    1.5933  -1.4237     -6.63   -5.8126    3.7433
# x3  -0.75345   -2.2718  ...  0.045122   2.9241   10.4849   10.8867  -0.40215
# x4  -0.61251  -0.73535  ...    -1.678  0.66119  -0.42113  -0.52846   -1.2953
# x5         0         0  ...         1        1         1         1         1
#
# ...

# %%
import random

train_x = []
for i in range(60):
    index = random.randint(0, 22) + i*23;
    if index < len(x1):
        train_x.append([float(x1[index]), float(x2[index]), float(x3[index]), float(x4[index]), float(x5[index])])
    else: 
        train_x.append([float(x1[len(x1)-1]), float(x2[len(x1)-1]), float(x3[len(x1)-1]), float(x4[len(x1)-1]), float(x5[len(x1)-1])])
        
table = pd.DataFrame({})
for i in range(len(train_x)):
    table[i+1] = [train_x[i][0], train_x[i][1], train_x[i][2], train_x[i][3], train_x[i][4]]
table.index = ["x1", "x2", "x3", "x4", "x5"]
table.head()
# Out:
#          1        2        3       4       5        6       7       8   \
# x1  2.09220  1.14320  1.79390  3.7935  3.3669 -1.04010 -0.2062  0.5706
# x2 -6.81000 -3.74130 -1.11740  7.9853 -5.1856  9.39870  9.2207 -0.0248
# x3  8.46360  5.57770  1.54540 -2.5477  3.6935  0.85998 -3.7044  1.2421
# x4 -0.60216 -0.63578 -0.26079 -1.8720 -1.1427 -5.33360 -6.8103 -0.5621
# x5  0.00000  0.00000  0.00000  0.0000  0.0000  0.00000  0.0000  0.0000
#
#          9        10  ...        51      52       53       54       55  \
# x1   3.9663  2.41960  ... -6.336400 -3.2778 -6.73870 -2.56400 -6.65100
# x2  10.1684  6.46650  ...  9.284800  1.8023  6.98790 -1.70510  6.79340
# x3  -4.1131 -0.75688  ...  0.014275  0.1805  0.67833  1.50260  0.68604
# x4  -4.6056  0.22800  ... -6.784400 -2.3931 -7.58870  0.32757 -7.58870
# x5   0.0000  0.00000  ...  1.000000  1.0000  1.00000  1.00000  1.00000
#
#         56        57       58      59       60
# x1  1.2080 -3.724400 -1.10050 -1.5851 -2.54190
# ...

# %%
w = []
for i in range(10):
    l = []
    for j in range(5):
        l.append(random.uniform(-1, 1))
    w.append(l)
    
table = pd.DataFrame({})
for i in range(len(w)):
    table[i+1] = [w[i][0], w[i][1], w[i][2], w[i][3], w[i][4]]
table.index = ["x1", "x2", "x3", "x4", "x5"]
table.head()
# Out:
#           1         2         3         4         5         6         7   \
# x1 -0.067832 -0.098824  0.192561 -0.978618 -0.358523  0.295791  0.711485
# x2 -0.103513  0.289086  0.207506 -0.604912 -0.255222 -0.473018 -0.173483
# x3  0.568301  0.032589 -0.744250  0.552151 -0.956922 -0.152992  0.610592
# x4 -0.395847 -0.430935 -0.396630  0.992582 -0.536997 -0.615184  0.206241
# x5  0.615346 -0.123073  0.838168  0.048550  0.016767  0.176262  0.166531
#
#           8         9         10
# x1  0.732408  0.215126  0.113854
# x2  0.975562  0.255179  0.012764
# x3 -0.670576 -0.751715 -0.767548
# x4  0.778195 -0.531194 -0.937311
# x5 -0.000683 -0.695335 -0.151526

# %%
import math

for i in range(60):
    d_min = math.sqrt((train_x[i][0]-w[0][0])**2 + (train_x[i][1]-w[0][1])**2 + (train_x[i][2]-w[0][2])**2 + (train_x[i][3]-w[0][3])**2+ (train_x[i][4]-w[0][4])**2)
    index = 0
    for j in range(1, 10):
        d = math.sqrt((train_x[i][0]-w[j][0])**2 + (train_x[i][1]-w[j][1])**2 + (train_x[i][2]-w[j][2])**2 + (train_x[i][3]-w[j][3])**2+ (train_x[i][4]-w[j][4])**2)
        if d < d_min:
            d_min = d
            index = j
    for j in range(5):
        w[index][j] += 0.04*(train_x[i][j] - w[index][j])
        
table = pd.DataFrame({})
for i in range(len(w)):
    table[i+1] = [x1[i], x2[i], x3[i], x4[i], x5[i]]
table.index = ["x1", "x2", "x3", "x4", "x5"]
table.head()
# Out:
#           1        2        3        4        5        6        7         8   \
# x1    3.6216   4.5459    3.866   3.4566  0.32924   4.3684   3.5912    2.0922
# x2    8.6661   8.1674  -2.6383   9.5228  -4.4552   9.6718   3.0129     -6.81
# x3   -2.8073  -2.4586   1.9242  -4.0112   4.5718  -3.9606  0.72888    8.4636
# x4  -0.44699  -1.4621  0.10645  -3.5944  -0.9888  -3.1625  0.56421  -0.60216
# x5         0        0        0        0        0        0        0         0
#
#           9         10
# x1    3.2032    1.5356
# x2    5.7588    9.1772
# x3  -0.75345   -2.2718
# x4  -0.61251  -0.73535
# x5         0         0

# %%
cluster = []
x = []
for i in range(len(x1)):
    x.append([float(x1[i]), float(x2[i]), float(x3[i]), float(x4[i]), float(x5[i])])
    
for i in range(len(x)):
    d_min = math.sqrt((x[i][0]-w[0][0])**2 + (x[i][1]-w[0][1])**2 + (x[i][2]-w[0][2])**2 + (x[i][3]-w[0][3])**2+ (x[i][4]-w[0][4])**2)
    index = 0
    for j in range(1, 10):
        d = math.sqrt((x[i][0]-w[j][0])**2 + (x[i][1]-w[j][1])**2 + (x[i][2]-w[j][2])**2 + (x[i][3]-w[j][3])**2+ (x[i][4]-w[j][4])**2)
        if d < d_min:
            d_min = d
            index = j
    cluster.append(index+1) 
    
table = pd.DataFrame({})
for i in range(len(cluster)):
    table[i+1] = [x1[i], x2[i], x3[i], x4[i], x5[i], cluster[i]]
table.index = ["x1", "x2", "x3", "x4", "x5", "cluster"]
table
# Out:
#              1        2        3        4        5        6        7     \
# x1         3.6216   4.5459    3.866   3.4566  0.32924   4.3684   3.5912
# x2         8.6661   8.1674  -2.6383   9.5228  -4.4552   9.6718   3.0129
# x3        -2.8073  -2.4586   1.9242  -4.0112   4.5718  -3.9606  0.72888
# x4       -0.44699  -1.4621  0.10645  -3.5944  -0.9888  -3.1625  0.56421
# x5              0        0        0        0        0        0        0
# cluster         8        8        7        8        7        8        3
#
#              8         9         10    ...      1363     1364      1365  \
# x1         2.0922    3.2032    1.5356  ...   -2.1668  -1.1667   -2.8391
# x2          -6.81    5.7588    9.1772  ...    1.5933  -1.4237     -6.63
# x3         8.4636  -0.75345   -2.2718  ...  0.045122   2.9241   10.4849
# x4       -0.60216  -0.61251  -0.73535  ...    -1.678  0.66119  -0.42113
# x5              0         0         0  ...         1        1         1
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

z = []
for i in range(5):
    l = []
    for j in range(len(x)):
        l.append(x[j][i])
    z.append(l)
    
s = [z[4][i]*10+10 for i in range(len(x5))]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(z[0], z[1], z[2], label='text', s=s, c=cluster)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(z[1], z[2], z[3], label='text', s=s, c=cluster)
